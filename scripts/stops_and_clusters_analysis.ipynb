# %%
import numpy as np
import pandas as pd

# %%
stations_df = pd.read_csv('stations.csv', ';')
clusters_df = pd.read_csv('district_stops.csv', ';')
districts_df = pd.read_csv('district_groups.csv', ';')
stations_df
# Out:
#       ID_STOP                           STOP_NAME  ID_TRANSPORT  \
# 0        2246               УЛ. КОРАБЛЕСТРОИТЕЛЕЙ             1
# 1        2424               УНИВЕРСАМ "ГАВАНСКИЙ"             1
# 2        2096              СТ. МЕТРО "ПРИМОРСКАЯ"             1
# 3       20878                 НОВОСМОЛЕНСКАЯ НАБ.             1
# 4        2278                        УЛ. НАХИМОВА             1
# 5        1672     МАЛЫЙ ПР. В.О.,УГ. НАЛИЧНОЙ УЛ.             1
# 6        4489                   ШКИПЕРСКИЙ ПРОТОК             1
# 7        2054                    СРЕДНИЙ ПР. В.О.             1
# 8        4490                    БОЛЬШОЙ ПР. В.О.             1
# 9        1434                       ВЕСЕЛЬНАЯ УЛ.             1
# 10      24986                                 NaN             1
# 11       2514  28-29 ЛИНИИ (ПО СРЕДНЕМУ ПР. В.О.)             1
# 12      27114                                 NaN             1
# 13      27115                                 NaN             1
# ...

# %%
stations_df[stations_df['ID_STOP'] == 1780]
# Out:
#      ID_STOP              STOP_NAME  ID_TRANSPORT       STOP_NAME_SHORT  \
# 257     1780  ПИСКАРЁВСКИЙ ПР., 50              1  ПИСКАРЁВСКИЙ ПР., 50
#
#      LATITUDE LONGITUDE
# 257  59,99004   30,4313

# %%
clusters_df[clusters_df['ID_STOP'] == 1664]
# Out:
#      ID_STOP  ID_STOP_GROUP  ID_TRANSPORT_DISTRICT  ID_DISTRICT_PART  \
# 816     1664            875                    617            1028.0
#
#      ID_DISTRICT  ID_PLAN_ZONE
# 816        114.0        2002.0

# %%
clusters_df[clusters_df['ID_STOP_GROUP'] == 1491]
# Out:
#       ID_STOP  ID_STOP_GROUP  ID_TRANSPORT_DISTRICT  ID_DISTRICT_PART  \
# 916      1780           1491                    553            1029.0
# 4668    16860           1491                    553            1029.0
#
#       ID_DISTRICT  ID_PLAN_ZONE
# 916         114.0        2002.0
# 4668        114.0        2002.0

# %%
stops_191 = '21667,3463,26825,1351,1531,2186,2223,1788,4376,3069,1664,1535,4215,2744,2730,4314,3374,3504,3086,3414,1892,17839,2058,2677,2010,1462,2377,7069,3615,3096,4589,2285,22481,20777'
clusters_191 = ""
for stop in stops_191.split(','):
